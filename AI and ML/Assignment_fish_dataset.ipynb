# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fish.csv')
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.shape
# Out:
# (159, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.isna().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df['Species'].value_counts()
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %%
sns.catplot(x = 'Species', y = 'Length1', data = df)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)
plt.show()

# %%
beam_df = df[df['Species'] == 'Bream']

# %%
x = beam_df[['Length1']]
y = beam_df['Weight']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=1,shuffle=True)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([563.80921884, 648.09316199, 400.50907899, 779.78682315])

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_test, y_pred)
# Out:
# 113.15275398418234

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7529784124006209

# %%
lr.score(x_train,y_train)
# Out:
# 0.8955594241998555

# %%
df.corr(numeric_only=True)
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
x1 = df[['Length2']]
y1 = df[['Weight']]

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.1,random_state=1,shuffle=True)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = lr.predict(x1_test)
y1_pred
# Out:
# array([[658.184568  ],
#        [175.35993499],
#        [507.30187019],
#        [220.62474433],
#        [145.18339542],
#        [552.56667953],
#        [205.53647455],
#        [477.12533062],
#        [160.2716652 ],
#        [265.88955368],
#        [205.53647455],
#        [235.71301411],
#        [-44.92880383],
#        [371.50744215],
#        [640.07864427],
#        [205.53647455]])

# %%
from sklearn.metrics import r2_score
r2_score(y1_test, y1_pred)
# Out:
# 0.8125831451462507

# %%
df.corr(numeric_only=True)
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.scatterplot(x = 'Weight',y = 'Length2', data = df)
plt.plot(x1_test,y1_pred,color = 'red')
plt.show()

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
beam1_df = df[df['Species'] == 'Bream']
x2 = beam1_df[['Length1', 'Length2', 'Length3', 'Height', 'Width']]
y2 = beam1_df['Weight']

# %%
from sklearn.model_selection import train_test_split

x2_train, x2_test, y2_train, y2_test = train_test_split(
    x2, y2, test_size=0.10, random_state=1, shuffle=True
)

# %%
from sklearn.linear_model import LinearRegression
ls = LinearRegression()
ls.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
y2_pred = ls.predict(x2_test)
y2_pred
# Out:
# array([572.574665  , 585.95919381, 378.9673958 , 939.54731219])

# %%
from sklearn.metrics import r2_score
r2_score(y2_test,y2_pred)
# Out:
# 0.9577340644713884

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y2_test,y2_pred)
# Out:
# 46.80507197103905

# %%
df.corr(numeric_only=True)
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
new_bream = np.array([[30.5, 32.0, 36.5, 14.2, 5.0]])

# Predict
predicted_weight = ls.predict(new_bream)
print(f"Predicted weight of the new Bream: {predicted_weight[0]:.2f}")
# Out:
# Predicted weight of the new Bream: 520.79
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import PolynomialFeatures
beam1_df = df[df['Species'] == 'Bream']
X = beam1_df[['Length1', 'Length2', 'Length3', 'Height', 'Width']]
y = beam1_df['Weight']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.metrics import mean_squared_error
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred_linear = lin_reg.predict(X_test)
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)
print(f"Linear Regression -> MSE: {mse_linear:.2f}, R2: {r2_linear:.2f}")
# Out:
# Linear Regression -> MSE: 3048.44, R2: 0.93

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

poly_reg = LinearRegression()
poly_reg.fit(X_train_poly, y_train)
y_pred_poly = poly_reg.predict(X_test_poly)

# Evaluation
mse_poly = mean_squared_error(y_test, y_pred_poly)
r2_poly = r2_score(y_test, y_pred_poly)
print(f"Polynomial Regression (deg 2) -> MSE: {mse_poly:.2f}, R2: {r2_poly:.2f}")
# Out:
# Polynomial Regression (deg 2) -> MSE: 896484.05, R2: -18.79
