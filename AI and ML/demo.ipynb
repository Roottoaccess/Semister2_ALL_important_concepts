# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Amazon_realtime.csv')
df.head(8)
# Out:
#                                                Title   Price  \
# 0  Lava O3 (Glossy Blue, 3 GB RAM, 64 GB Storage)...  ₹5,798
# 1  Lava O3 Pro (Glossy Purple, 4 GB RAM, 64 GB St...  ₹6,698
# 2  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...  ₹8,499
# 3  Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...  ₹6,499
# 4  Redmi A4 5G (Sparkle Purple, 4GB RAM, 64GB Sto...  ₹8,499
# 5  Redmi A4 5G (Starry Black, 4GB RAM, 64GB Stora...  ₹8,499
# 6  realme NARZO N61 (Voyage Blue,4GB RAM+64GB Sto...  ₹7,498
# 7  Redmi A4 5G (Starry Black, 4GB RAM, 128GB Stor...  ₹9,499
#
#                Rating
# 0  3.8 out of 5 stars
# 1  3.9 out of 5 stars
# 2  3.7 out of 5 stars
# 3  4.0 out of 5 stars
# 4  3.9 out of 5 stars
# 5  3.9 out of 5 stars
# 6  4.0 out of 5 stars
# 7  3.9 out of 5 stars

# %%
df.isna()
# Out:
#     Title  Price  Rating
# 0   False  False   False
# 1   False  False   False
# 2   False  False   False
# 3   False  False   False
# 4   False  False   False
# 5   False  False   False
# 6   False  False   False
# 7   False  False   False
# 8   False  False   False
# 9   False  False   False
# 10  False  False   False
# 11  False  False   False
# 12  False  False    True
# 13  False  False   False
# 14  False  False   False
# 15  False  False   False
# 16  False  False   False
# 17  False  False   False
# 18  False  False   False
# 19  False  False   False
# 20  False  False   False
# 21  False  False   False
# 22  False  False   False
# 23  False  False   False
# 24  False  False    True
# 25  False  False   False
# 26  False  False   False
# 27  False  False   False

# %%
df['Rating']
# Out:
# 0     3.8 out of 5 stars
# 1     3.9 out of 5 stars
# 2     3.7 out of 5 stars
# 3     4.0 out of 5 stars
# 4     3.9 out of 5 stars
# 5     3.9 out of 5 stars
# 6     4.0 out of 5 stars
# 7     3.9 out of 5 stars
# 8     3.9 out of 5 stars
# 9     4.0 out of 5 stars
# 10    3.7 out of 5 stars
# 11    3.7 out of 5 stars
# 12                   NaN
# 13    4.0 out of 5 stars
# 14    4.2 out of 5 stars
# 15    3.7 out of 5 stars
# 16    4.0 out of 5 stars
# 17    4.2 out of 5 stars
# 18    3.7 out of 5 stars
# 19    4.1 out of 5 stars
# 20    4.0 out of 5 stars
# 21    3.8 out of 5 stars
# 22    2.9 out of 5 stars
# 23    4.1 out of 5 stars
# 24                   NaN
# 25    3.4 out of 5 stars
# 26    4.2 out of 5 stars
# 27    3.8 out of 5 stars
# Name: Rating, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.columns
# Out:
# Index(['Title', 'Price', 'Rating'], dtype='object')

# %%
df['Title'].value_counts()
# Out:
# Title
# Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands| 25W Fast Charging | 4 Gen. of OS Upgrades | Without Charger                         2
# Lava O3 (Glossy Blue, 3 GB RAM, 64 GB Storage) | Biggest 6.75" HD+ Display | 13MP AI Dual Rear Camera | 5000 mAh Battery | Secure Face Unlock | Fingerprint Reader | Charger & Phone-Cover in Box           1
# Samsung Galaxy M06 5G (Blazing Black, 4GB RAM, 128 GB Storage) | MediaTek Dimensity 6300 | AnTuTu Score 422K+ | 12 5G Bands | 25W Fast Charging | 4 Gen. of OS Upgrades | Without Charger                   1
# Tecno POP 9 (Magic Skin Green, 3GB+64GB) |India's 1st Mediatek G50 | IP54 Rated | IR Remote | Dual Speaker with DTS | 36 Month Lag Free Fluency | 15W Fast Charging Support | 5000 mAh Battery              1
# ...

# %%
sns.countplot(x='Price',data=df); plt.show()

# %%
sns.countplot(y='Price',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Price'>

# %%
df
# Out:
#                                                 Title    Price  \
# 0   Lava O3 (Glossy Blue, 3 GB RAM, 64 GB Storage)...   ₹5,798
# 1   Lava O3 Pro (Glossy Purple, 4 GB RAM, 64 GB St...   ₹6,698
# 2   Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...   ₹8,499
# 3   Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   ₹6,499
# 4   Redmi A4 5G (Sparkle Purple, 4GB RAM, 64GB Sto...   ₹8,499
# 5   Redmi A4 5G (Starry Black, 4GB RAM, 64GB Stora...   ₹8,499
# 6   realme NARZO N61 (Voyage Blue,4GB RAM+64GB Sto...   ₹7,498
# 7   Redmi A4 5G (Starry Black, 4GB RAM, 128GB Stor...   ₹9,499
# 8   Redmi A4 5G (Sparkle Purple, 4GB RAM, 128GB St...   ₹9,499
# 9   realme NARZO N61 (Voyage Blue,6GB RAM+128GB St...   ₹8,498
# 10  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 12...   ₹9,199
# 11  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...   ₹8,499
# 12                  Tantra I Have a Smart Phone - Red     ₹699
# 13  realme NARZO N61 (Marble Black, 4GB RAM+64GB S...   ₹7,498
# ...

# %%
df.head()
# Out:
#                                                Title   Price  \
# 0  Lava O3 (Glossy Blue, 3 GB RAM, 64 GB Storage)...  ₹5,798
# 1  Lava O3 Pro (Glossy Purple, 4 GB RAM, 64 GB St...  ₹6,698
# 2  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...  ₹8,499
# 3  Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...  ₹6,499
# 4  Redmi A4 5G (Sparkle Purple, 4GB RAM, 64GB Sto...  ₹8,499
#
#                Rating
# 0  3.8 out of 5 stars
# 1  3.9 out of 5 stars
# 2  3.7 out of 5 stars
# 3  4.0 out of 5 stars
# 4  3.9 out of 5 stars

# %%
df
# Out:
#                                                 Title    Price  \
# 0   Lava O3 (Glossy Blue, 3 GB RAM, 64 GB Storage)...   ₹5,798
# 1   Lava O3 Pro (Glossy Purple, 4 GB RAM, 64 GB St...   ₹6,698
# 2   Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...   ₹8,499
# 3   Samsung Galaxy M05 (Mint Green, 4GB RAM, 64 GB...   ₹6,499
# 4   Redmi A4 5G (Sparkle Purple, 4GB RAM, 64GB Sto...   ₹8,499
# 5   Redmi A4 5G (Starry Black, 4GB RAM, 64GB Stora...   ₹8,499
# 6   realme NARZO N61 (Voyage Blue,4GB RAM+64GB Sto...   ₹7,498
# 7   Redmi A4 5G (Starry Black, 4GB RAM, 128GB Stor...   ₹9,499
# 8   Redmi A4 5G (Sparkle Purple, 4GB RAM, 128GB St...   ₹9,499
# 9   realme NARZO N61 (Voyage Blue,6GB RAM+128GB St...   ₹8,498
# 10  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 12...   ₹9,199
# 11  Samsung Galaxy M06 5G (Sage Green, 4GB RAM, 64...   ₹8,499
# 12                  Tantra I Have a Smart Phone - Red     ₹699
# 13  realme NARZO N61 (Marble Black, 4GB RAM+64GB S...   ₹7,498
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   28 non-null     object
#  1   Price   28 non-null     object
#  2   Rating  26 non-null     object
# dtypes: object(3)
# memory usage: 804.0+ bytes
