# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('stock_infosys.csv')
df.head()
# Out:
#            Date    Close     Open     High      Low  Vol-Million  Change %
# 0  Jun 18, 2018  1269.20  1281.80  1291.00  1264.05         2.86     -0.01
# 1  Jun 15, 2018  1281.25  1237.00  1291.50  1235.00         9.98      0.03
# 2  Jun 14, 2018  1239.70  1253.00  1253.00  1234.10         3.80     -0.02
# 3  Jun 13, 2018  1264.80  1256.86  1273.93  1256.86         2.88      0.01
# 4  Jun 12, 2018  1248.63  1255.82  1261.28  1240.64         3.92      0.00

# %%
df.shape
# Out:
# (249, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         249 non-null    object
#  1   Close        249 non-null    float64
#  2   Open         249 non-null    float64
#  3   High         249 non-null    float64
#  4   Low          249 non-null    float64
#  5   Vol-Million  249 non-null    float64
#  6   Change %     249 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.7+ KB

# %%
# Formatting the date column
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date    Close     Open     High      Low  Vol-Million  Change %
# 0 2018-06-18  1269.20  1281.80  1291.00  1264.05         2.86     -0.01
# 1 2018-06-15  1281.25  1237.00  1291.50  1235.00         9.98      0.03
# 2 2018-06-14  1239.70  1253.00  1253.00  1234.10         3.80     -0.02
# 3 2018-06-13  1264.80  1256.86  1273.93  1256.86         2.88      0.01
# 4 2018-06-12  1248.63  1255.82  1261.28  1240.64         3.92      0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         249 non-null    datetime64[ns]
#  1   Close        249 non-null    float64
#  2   Open         249 non-null    float64
#  3   High         249 non-null    float64
#  4   Low          249 non-null    float64
#  5   Vol-Million  249 non-null    float64
#  6   Change %     249 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 13.7 KB

# %%
df.head() # Same range data values so no need of feture scalling
# Out:
#         Date    Close     Open     High      Low  Vol-Million  Change %
# 0 2018-06-18  1269.20  1281.80  1291.00  1264.05         2.86     -0.01
# 1 2018-06-15  1281.25  1237.00  1291.50  1235.00         9.98      0.03
# 2 2018-06-14  1239.70  1253.00  1253.00  1234.10         3.80     -0.02
# 3 2018-06-13  1264.80  1256.86  1273.93  1256.86         2.88      0.01
# 4 2018-06-12  1248.63  1255.82  1261.28  1240.64         3.92      0.00

# %%
df['Date'] = df['Date'].dt.strftime('%Y%j')
df.head()
# Out:
#       Date    Close     Open     High      Low  Vol-Million  Change %
# 0  2018169  1269.20  1281.80  1291.00  1264.05         2.86     -0.01
# 1  2018166  1281.25  1237.00  1291.50  1235.00         9.98      0.03
# 2  2018165  1239.70  1253.00  1253.00  1234.10         3.80     -0.02
# 3  2018164  1264.80  1256.86  1273.93  1256.86         2.88      0.01
# 4  2018163  1248.63  1255.82  1261.28  1240.64         3.92      0.00

# %%
x = df.iloc[:,[0,2,3,4,5]]
y = df.Close

# %%
x
# Out:
#         Date     Open     High      Low  Vol-Million
# 0    2018169  1281.80  1291.00  1264.05         2.86
# 1    2018166  1237.00  1291.50  1235.00         9.98
# 2    2018165  1253.00  1253.00  1234.10         3.80
# 3    2018164  1256.86  1273.93  1256.86         2.88
# 4    2018163  1255.82  1261.28  1240.64         3.92
# ..       ...      ...      ...      ...          ...
# 244  2017174   945.00   949.15   938.00         3.20
# 245  2017173   947.70   968.70   935.10         4.73
# 246  2017172   945.00   949.00   936.05         1.87
# 247  2017171   935.00   946.90   934.05         2.59
# 248  2017170   939.95   940.25   928.00         3.43
#
# [249 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=1,shuffle=True)

# %%
x_train.shape
# Out:
# (199, 5)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_test,y_test) # This is the regression so MAE, RMSE
# Out:
# 0.9893881915006063

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error
y_pred = dtr.predict(x_test)
mean_squared_error(y_test, y_pred)
# Out:
# 142.84448199999994

# %%
y_pred
# Out:
# array([1183.8 ,  935.45,  987.7 ,  923.9 , 1152.7 ,  994.05, 1164.55,
#         988.4 ,  896.  , 1250.17,  943.35,  884.05, 1035.6 ,  908.25,
#        1013.1 , 1152.7 ,  909.55, 1143.45, 1180.75, 1163.4 ,  983.75,
#        1189.95, 1180.8 ,  912.25, 1020.85, 1021.3 ,  957.05,  951.95,
#        1180.8 ,  972.05,  968.25, 1128.05, 1176.45,  968.25,  941.  ,
#         984.7 , 1185.8 , 1171.45, 1216.7 ,  935.45,  914.95, 1179.5 ,
#        1151.35, 1152.7 , 1194.55, 1022.9 , 1182.55, 1228.3 , 1170.7 ,
#        1264.8 ])

# %%
df.columns
# Out:
# Index(['Date', 'Close', 'Open', 'High', 'Low', 'Vol-Million', 'Change %'], dtype='object')

# %%
from sklearn.tree import export_text
export_text(dtr, feature_names = ['Date','Open','High','Low','Vol-Million'])
# Out:
# '|--- Low <= 1044.15\n|   |--- Low <= 948.38\n|   |   |--- High <= 921.55\n|   |   |   |--- High <= 899.65\n|   |   |   |   |--- Low <= 876.23\n|   |   |   |   |   |--- Open <= 892.80\n|   |   |   |   |   |   |--- value: [878.70]\n|   |   |   |   |   |--- Open >  892.80\n|   |   |   |   |   |   |--- value: [875.40]\n|   |   |   |   |--- Low >  876.23\n|   |   |   |   |   |--- High <= 887.67\n|   |   |   |   |   |   |--- value: [883.75]\n|   |   |   |   |   |--- High >  887.67\n|   |   |   |   |   |   |--- Date <= 2017253.00\n|   |   |   |   |   |   |   |--- value: [884.30]\n|   |   |   |   |   |   |--- Date >  2017253.00\n|   |   |   |   |   |   |   |--- value: [884.05]\n|   |   |   |--- High >  899.65\n|   |   |   |   |--- High <= 909.95\n|   |   |   |   |   |--- Low <= 894.65\n|   |   |   |   |   |   |--- Vol-Million <= 19.70\n|   |   |   |   |   |   |   |--- Low <= 891.17\n|   |   |   |   |   |   |   |   |--- Low <= 889.55\n|   |   |   |   |   |   |   |   |   |--- value: [895.35]\
# ...
