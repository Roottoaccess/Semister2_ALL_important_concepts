# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
x = [5 , 2 , 6 , 4 , 8]
plt.pie(x)
plt.show()

# %%
x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]

plt.scatter(x , y)
plt.show()

# %%
x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]

plt.bar(x, y)
plt.show()

# %%
x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]

plt.plot(x , y)
plt.show()

# %%
y = [10, 5, 8, 4, 2]
plt.hist(y)
plt.show()

# %%
df = pd.read_csv('salary.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.Salary.value_counts().plot.pie(autopct = "%.1f")
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.shape
# Out:
# (30, 3)

# %%
df['Gender'] = 'Male'

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary Gender
# 0           0              1.2  39344.0   Male
# 1           1              1.4  46206.0   Male
# 2           2              1.6  37732.0   Male
# 3           3              2.1  43526.0   Male
# 4           4              2.3  39892.0   Male

# %%
df.shape
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary', 'Gender'], dtype='object')

# %%
df.iloc[14:, df.columns.get_loc('Gender')] = 'Female'
# df.head()

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary Gender
# 0           0              1.2  39344.0   Male
# 1           1              1.4  46206.0   Male
# 2           2              1.6  37732.0   Male
# 3           3              2.1  43526.0   Male
# 4           4              2.3  39892.0   Male

# %%
sns.countplot(x = 'Gender', data = df)
plt.show()

# %%
sns.relplot(x= 'Salary', y = 'Gender', data = df, hue = 'Gender')
plt.show()

# %%
sns.swarmplot(data=df,x="Gender",y='Salary')
plt.show()

# %%
sns.violinplot(data=df,x="Gender",y='Salary')
plt.show()

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# Gender             0
# dtype: int64

# %%
# Applying the Lable Encoding to the follow data....
# x = [['Gender']]
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# le.fit_transform(x)

# x = ['Gender']
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# for i in x:
#     df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary  Gender
# 0            0              1.2   39344.0    Male
# 1            1              1.4   46206.0    Male
# 2            2              1.6   37732.0    Male
# 3            3              2.1   43526.0    Male
# 4            4              2.3   39892.0    Male
# 5            5              3.0   56643.0    Male
# 6            6              3.1   60151.0    Male
# 7            7              3.3   54446.0    Male
# 8            8              3.3   64446.0    Male
# 9            9              3.8   57190.0    Male
# 10          10              4.0   63219.0    Male
# 11          11              4.1   55795.0    Male
# 12          12              4.1   56958.0    Male
# 13          13              4.2   57082.0    Male
# 14          14              4.6   61112.0  Female
# 15          15              5.0   67939.0  Female
# 16          16              5.2   66030.0  Female
# 17          17              5.4   83089.0  Female
# ...

# %%
# Finding the outlier
# df.columns
sns.boxplot(x = 'Salary', data = df)
plt.show()

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary Gender
# 0              1.2  39344.0   Male
# 1              1.4  46206.0   Male
# 2              1.6  37732.0   Male
# 3              2.1  43526.0   Male
# 4              2.3  39892.0   Male

# %%
# Applying the feature scalling in the dataset
x = df[['YearsExperience','Salary']]
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
mm.fit_transform(x)
# Out:
# array([[0.        , 0.01904087],
#        [0.0212766 , 0.1000945 ],
#        [0.04255319, 0.        ],
#        [0.09574468, 0.06843846],
#        [0.11702128, 0.02551382],
#        [0.19148936, 0.22337586],
#        [0.20212766, 0.26481219],
#        [0.22340426, 0.19742499],
#        [0.22340426, 0.31554453],
#        [0.27659574, 0.229837  ],
#        [0.29787234, 0.30105126],
#        [0.30851064, 0.21335932],
#        [0.30851064, 0.22709662],
#        [0.31914894, 0.2285613 ],
#        [0.36170213, 0.27616348],
#        [0.40425532, 0.35680369],
#        [0.42553191, 0.33425467],
#        [0.44680851, 0.53575478],
#        [0.5106383 , 0.51537916],
#        [0.5212766 , 0.66393811],
#        [0.60638298, 0.63792818],
#        [0.63829787, 0.7151193 ],
#        [0.72340426, 0.75089771],
#        [0.75531915, 0.89866525],
#        [0.80851064, 0.84691708],
#        [0.84042553, 0.80145287],
#        [0.89361702, 0.93595559],
#        [0.90425532, 0.88476258],
# ...

# %%
df.head()
# Out:
#    YearsExperience   Salary Gender
# 0              1.2  39344.0   Male
# 1              1.4  46206.0   Male
# 2              1.6  37732.0   Male
# 3              2.1  43526.0   Male
# 4              2.3  39892.0   Male

# %%
x = df['Gender']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(x)

# %%
df.head()
# Out:
#    YearsExperience   Salary  Gender
# 0              1.2  39344.0       1
# 1              1.4  46206.0       1
# 2              1.6  37732.0       1
# 3              2.1  43526.0       1
# 4              2.3  39892.0       1

# %%
df
# Out:
#     YearsExperience    Salary  Gender
# 0               1.2   39344.0       1
# 1               1.4   46206.0       1
# 2               1.6   37732.0       1
# 3               2.1   43526.0       1
# 4               2.3   39892.0       1
# 5               3.0   56643.0       1
# 6               3.1   60151.0       1
# 7               3.3   54446.0       1
# 8               3.3   64446.0       1
# 9               3.8   57190.0       1
# 10              4.0   63219.0       1
# 11              4.1   55795.0       1
# 12              4.1   56958.0       1
# 13              4.2   57082.0       1
# 14              4.6   61112.0       0
# 15              5.0   67939.0       0
# 16              5.2   66030.0       0
# 17              5.4   83089.0       0
# 18              6.0   81364.0       0
# 19              6.1   93941.0       0
# 20              6.9   91739.0       0
# 21              7.2   98274.0       0
# 22              8.0  101303.0       0
# 23              8.3  113813.0       0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  YearsExperience    Salary    Gender
# YearsExperience         1.000000  0.978242 -0.821046
# Salary                  0.978242  1.000000 -0.821571
# Gender                 -0.821046 -0.821571  1.000000

# %%
# Drawing the heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
x = ['YearsExperience']; y = ['Salary']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.25,random_state=1, shuffle=True)

# %%
df.describe()
# Out:
#        YearsExperience         Salary     Gender
# count        30.000000      30.000000  30.000000
# mean          5.413333   76004.000000   0.466667
# std           2.837888   27414.429785   0.507416
# min           1.200000   37732.000000   0.000000
# 25%           3.300000   56721.750000   0.000000
# 50%           4.800000   65238.000000   0.000000
# 75%           7.800000  100545.750000   1.000000
# max          10.600000  122392.000000   1.000000

# %%
# Finding the outlier from one column
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)

# Inter Quantile Range
IQR = Q3 - Q1
print(f'The Inter Quantile Range: {IQR}')

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f'{lower_bound} -- {upper_bound}')
outlier = df[(df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)]
outlier
# Out:
# The Inter Quantile Range: 43824.0
# -9014.25 -- 166281.75
# Empty DataFrame
# Columns: [YearsExperience, Salary, Gender]
# Index: []
