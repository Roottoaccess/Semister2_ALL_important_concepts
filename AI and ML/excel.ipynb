# %%
import pandas as pd

df = pd.read_excel("convert_to_excel.xlsx")
df
# Out:
#      Unnamed: 0   ProductID  \
# 0             0  B0F6DDSHP4
# 1             2  B0CQK691XQ
# 2             3  B08D7NCQ5N
# 3             4  B0D7PT7RSK
# 4             5  B09RSY4RDR
# ..          ...         ...
# 429         833  B0DK96DPY6
# 430         837  B0CVLB99YR
# 431         850  B0D8BZDPXB
# 432         857  B0CCVGXFG7
# 433         874  B0D6WD2QSQ
#
#                                                  Title  Selling Price  \
# 0    HORPIN Drone with 4k Camera Foldable 1080P HD ...       0.008132
# 1    Popsugar Off Roader Rechargeable Remote Contro...       0.005405
# 2    Cable World Plastic Battery Operated Convertin...       0.001768
# 3    Hot Wheels Batman™ Toy Car 5-Pack, Set of 5 1:...       0.003891
# 4    Party Propz Birthday Decoration Items - 60 Pcs...       0.001305
# ..                                                 ...            ...
# 429  Noise Master Buds, Sound by Bose in-Ear Blueto...       0.036315
# ...
