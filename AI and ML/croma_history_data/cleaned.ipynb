# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Cleaned_1.csv')
df.head(2)
# Out:
#     ProductID                                                URL  \
# 0  B0D6NMXQ2V  https://www.amazon.in/dp/B0D6NMXQ2V?th=1&psc=1...
# 1  B0CZ3ZPD8B  https://www.amazon.in/dp/B0CZ3ZPD8B?th=1&psc=1...
#
#                                                Title  Selling Price     MRP  \
# 0  HP H150 Wireless in Ear Earbuds, Compatible wi...          499.0  2499.0
# 1  boAt Airdopes 311 Pro, 50HRS Battery, Fast Cha...          799.0  4990.0
#
#    Discount  Rating  Rating_Count  \
# 0      0.80     2.8        1037.0
# 1      0.84     3.4        4246.0
#
#                                             Category Subcategory
# 0  Electronics > Headphones, Earbuds & Accessorie...      In-Ear
# 1  Electronics > Headphones, Earbuds & Accessorie...      In-Ear

# %%
df.shape
# Out:
# (2006, 10)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductID      2006 non-null   object
#  1   URL            2006 non-null   object
#  2   Title          2006 non-null   object
#  3   Selling Price  1990 non-null   float64
#  4   MRP            1983 non-null   float64
#  5   Discount       1983 non-null   float64
#  6   Rating         1997 non-null   float64
#  7   Rating_Count   1993 non-null   float64
#  8   Category       1978 non-null   object
#  9   Subcategory    1978 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 156.8+ KB

# %%
df.isna().sum()
# Out:
# ProductID         0
# URL               0
# Title             0
# Selling Price    16
# MRP              23
# Discount         23
# Rating            9
# Rating_Count     13
# Category         28
# Subcategory      28
# dtype: int64

# %%
df['New_Columns_Category'] = df['Category'].value_counts() == 1

# %%
df.head()
# Out:
#     ProductID                                                URL  \
# 0  B0D6NMXQ2V  https://www.amazon.in/dp/B0D6NMXQ2V?th=1&psc=1...
# 1  B0CZ3ZPD8B  https://www.amazon.in/dp/B0CZ3ZPD8B?th=1&psc=1...
# 2  B07PR1CL3S  https://www.amazon.in/dp/B07PR1CL3S?th=1&psc=1...
# 3  B0C8JB3G5W  https://www.amazon.in/dp/B0C8JB3G5W?th=1&psc=1...
# 4  B07YNV41FT  https://www.amazon.in/dp/B07YNV41FT?th=1&psc=1...
#
#                                                Title  Selling Price     MRP  \
# 0  HP H150 Wireless in Ear Earbuds, Compatible wi...          499.0  2499.0
# 1  boAt Airdopes 311 Pro, 50HRS Battery, Fast Cha...          799.0  4990.0
# 2  Boat Rockerz 450/450R, 15 HRS Battery, 40mm Dr...         1399.0  3990.0
# 3  OnePlus Nord Buds 2r True Wireless in Ear Earb...         1799.0  2299.0
# 4  Zebronics ZEB-COUNTY 3W Wireless Bluetooth Por...          499.0   999.0
#
#    Discount  Rating  Rating_Count  \
# 0      0.80     2.8        1037.0
# 1      0.84     3.4        4246.0
# ...

# %%
df.drop('New_Columns_Category', axis = 1, inplace=True)

# %%
df.head(2)
# Out:
#     ProductID                                                URL  \
# 0  B0D6NMXQ2V  https://www.amazon.in/dp/B0D6NMXQ2V?th=1&psc=1...
# 1  B0CZ3ZPD8B  https://www.amazon.in/dp/B0CZ3ZPD8B?th=1&psc=1...
#
#                                                Title  Selling Price     MRP  \
# 0  HP H150 Wireless in Ear Earbuds, Compatible wi...          499.0  2499.0
# 1  boAt Airdopes 311 Pro, 50HRS Battery, Fast Cha...          799.0  4990.0
#
#    Discount  Rating  Rating_Count  \
# 0      0.80     2.8        1037.0
# 1      0.84     3.4        4246.0
#
#                                             Category Subcategory
# 0  Electronics > Headphones, Earbuds & Accessorie...      In-Ear
# 1  Electronics > Headphones, Earbuds & Accessorie...      In-Ear

# %%
df.describe()
# Out:
#        Selling Price            MRP     Discount       Rating   Rating_Count
# count    1990.000000    1983.000000  1983.000000  1997.000000    1993.000000
# mean     5817.693209    9197.252260     0.516364     3.911424   12320.366533
# std     11267.463817   14472.292457     0.195303     0.529620   44180.865089
# min        60.000000     150.000000     0.010000     1.000000       2.000000
# 25%       699.000000    1899.000000     0.380000     3.700000     166.000000
# 50%      1699.000000    4300.000000     0.550000     4.000000    1056.000000
# 75%      5499.000000    9548.750000     0.660000     4.200000    4953.000000
# max    124999.000000  164999.000000     0.950000     5.000000  419585.000000

# %%
df.columns
# Out:
# Index(['ProductID', 'URL', 'Title', 'Selling Price', 'MRP', 'Discount',
#        'Rating', 'Rating_Count', 'Category', 'Subcategory'],
#       dtype='object')

# %%
sns.boxplot(x = 'Selling Price', data = df)
plt.show()

# %%
sns.boxplot(x = 'MRP', data = df)
plt.show()

# %%
df.columns
# Out:
# Index(['ProductID', 'URL', 'Title', 'Selling Price', 'MRP', 'Discount',
#        'Rating', 'Rating_Count', 'Category', 'Subcategory'],
#       dtype='object')

# %%
sns.boxplot(x = 'Category', data = df)
plt.show()

# %%
sns.boxplot(x = 'Subcategory', data = df)
plt.show()

# %%
df.value_counts()
# Out:
# ProductID   URL                                                            Title                                                                                                                                                                                                    Selling Price  MRP           Discount  Rating    Rating_Count   Category                                                                                                           Subcategory
# B0DNFPSF15  https://www.amazon.in/dp/B0DNFPSF15?th=1&psc=1&language=en_IN  Diamond Android SystemTouchCar Screen10.1In Car Stereo Android System for Car Wireless Android Auto Car Play,4GB/64GB,4th GenCar Display Screen Android System for Car|GPS,Bluetooth,WiFi,FM,AHD Camera  8999.000000    33000.000000  0.730000  3.600000  55.000000      Electronics > Car & Vehicle Electronics > Car Electronics > Car Audio > Car Stereos                                Car Stereos                      5
# ...

# %%
df["Subcategory"].value_counts()
# Out:
# Subcategory
# In-Ear                       581
# Remote Controls              174
# Bluetooth Speakers           156
# Soundbar Speakers            101
# Over-Ear                     101
#                             ...
# Notepads & Memo Books          1
# Head Cleaners                  1
# Audio & Video Accessories      1
# Full-Range                     1
# Computers & Accessories        1
# Name: count, Length: 193, dtype: int64
