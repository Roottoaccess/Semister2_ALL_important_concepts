# %%
import pandas as pd
import numpy as nb
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importig the dataset
df = pd.read_csv('500+.csv')
df.head()
# Out:
#                                        product_title rating() rating_count  \
# 0  Croma 140 cm (55 inch  4K Ultra HD Google TV w...      3.5           15
# 1  Croma 102 cm (40 inch  Full HD LED Smart Googl...      3.4           17
# 2  Croma 80 cm (32 inch  HD Ready LED Smart Googl...      3.8           32
# 3  Croma 127 cm (50 inch  4K Ultra HD LED Google ...        5            1
# 4  Westinghouse W2 Series 100 cm (40 inch  Full H...        3            2
#
#   selling_price    MRP  dicountvalue discount
# 0         30990  76500       45510.0  59% Off
# 1         15490  29900       14410.0  48% Off
# 2         10590  25000       14410.0  58% Off
# 3         28490  45500       17010.0  37% Off
# 4         13999  26999       13000.0  48% Off

# %%
df.shape
# Out:
# (455, 7)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_title  444 non-null    object
#  1   rating()       428 non-null    object
#  2   rating_count   421 non-null    object
#  3   selling_price  444 non-null    object
#  4   MRP            440 non-null    object
#  5   dicountvalue   396 non-null    float64
#  6   discount       439 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 25.0+ KB

# %%
df.isna().sum()
# Out:
# product_title    11
# rating()         27
# rating_count     34
# selling_price    11
# MRP              15
# dicountvalue     59
# discount         16
# dtype: int64
